# %%
import polars as pl

# %%
aau = pl.read_excel("/home/vandy/work/aplu_research/data/AAU Expenditures.xlsx", read_options={
        "header_row": False,  # We'll handle headers manually
        "skip_rows": 0
    })
aau
# Out:
# shape: (70, 78)
# ┌───────────────────────────────┬────────┬────────┬────────┬───┬────────┬────────┬────────┬────────┐
# │ Fiscal Year                   ┆ 2023   ┆ 2023_1 ┆ 2023_2 ┆ … ┆ 2013_3 ┆ 2013_4 ┆ 2013_5 ┆ 2013_6 │
# │ ---                           ┆ ---    ┆ ---    ┆ ---    ┆   ┆ ---    ┆ ---    ┆ ---    ┆ ---    │
# │ str                           ┆ str    ┆ str    ┆ str    ┆   ┆ i64    ┆ str    ┆ i64    ┆ i64    │
# ╞═══════════════════════════════╪════════╪════════╪════════╪═══╪════════╪════════╪════════╪════════╡
# │ Arizona State U.              ┆ 337271 ┆ 46290  ┆ 23210  ┆ … ┆ 62141  ┆ 21274  ┆ 54695  ┆ 13043  │
# │ Boston U.                     ┆ 409098 ┆ 20847  ┆ 8055   ┆ … ┆ 198497 ┆ 4503   ┆ 29966  ┆ 6795   │
# │ Brandeis U.                   ┆ 46654  ┆ 609    ┆ 2055   ┆ … ┆ 31421  ┆ -      ┆ 7207   ┆ 4181   │
# │ Brown U.                      ┆ 239549 ┆ 19737  ┆ 7733   ┆ … ┆ 70748  ┆ 4770   ┆ 28117  ┆ 4431   │
# ...
